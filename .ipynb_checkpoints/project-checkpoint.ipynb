# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt

# %%
tesla_data = yf.download('TSLA', start='2020-01-01', end='2023-01-01')
tesla_data_reset = tesla_data.reset_index()
tesla_first_five = tesla_data_reset.head()
tesla_first_five
# Out:
# [*********************100%***********************]  1 of 1 completed
#         Date       Open       High        Low      Close  Adj Close     Volume
# 0 2020-01-02  28.299999  28.713333  28.114000  28.684000  28.684000  142981500
# 1 2020-01-03  29.366667  30.266666  29.128000  29.534000  29.534000  266677500
# 2 2020-01-06  29.364668  30.104000  29.333332  30.102667  30.102667  151995000
# 3 2020-01-07  30.760000  31.441999  30.224001  31.270666  31.270666  268231500
# 4 2020-01-08  31.580000  33.232666  31.215334  32.809334  32.809334  467164500

# %%
url = 'https://www.macrotrends.net/stocks/charts/TSLA/tesla/revenue'
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.102 Safari/537.36'
}
response = requests.get(url, headers=headers)

if response.status_code == 200:
    soup = BeautifulSoup(response.text, 'html.parser')
    annual_table = soup.find_all('table', {'class': 'historical_data_table table'})[0]
    annual_data = []
    
    for row in annual_table.find('tbody').find_all('tr'):
        cols = row.find_all('td')
        year = cols[0].text.strip()
        revenue = cols[1].text.strip()
        annual_data.append([year, revenue])
    
    annual_df = pd.DataFrame(annual_data, columns=['Year', 'Revenue (Millions USD)'])
    annual_df['Year'] = annual_df['Year'].astype(int)
    recent_years_df = annual_df.sort_values(by='Year', ascending=False).head(5)
    print(recent_years_df)
else:
    print(f'Erro ao acessar a página: {response.status_code}')
# Out:
#    Year Revenue (Millions USD)
# 0  2023                $96,773
# 1  2022                $81,462
# 2  2021                $53,823
# 3  2020                $31,536
# 4  2019                $24,578

# %%
gme_data = yf.download('GME', start='2020-01-01', end='2024-01-01')
gme_data.reset_index(inplace=True)
print(gme_data.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
#         Date    Open    High     Low   Close  Adj Close    Volume
# 0 2020-01-02  1.5350  1.6175  1.5175  1.5775     1.5775  17814400
# 1 2020-01-03  1.5525  1.5625  1.4600  1.4700     1.4700  14175600
# 2 2020-01-06  1.4500  1.4775  1.4000  1.4625     1.4625  13579200
# 3 2020-01-07  1.4425  1.4575  1.3600  1.3800     1.3800  20912000
# 4 2020-01-08  1.3725  1.4625  1.3525  1.4300     1.4300  22517600

# %%
url = 'https://www.macrotrends.net/stocks/charts/GME/gamestop/revenue'
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.102 Safari/537.36'
}
response = requests.get(url, headers=headers)

if response.status_code == 200:
    soup = BeautifulSoup(response.text, 'html.parser')
    revenue_table = soup.find_all('table', {'class': 'historical_data_table table'})[0]
    revenue_data = []
    
    for row in revenue_table.find('tbody').find_all('tr'):
        cols = row.find_all('td')
        year = cols[0].text.strip()
        revenue = cols[1].text.strip()
        revenue_data.append([year, revenue])

    gme_revenue = pd.DataFrame(revenue_data, columns=['Year', 'Revenue (Millions USD)'])

    print(gme_revenue.tail())

else:
    print(f"Failed to retrieve data. HTTP Status code: {response.status_code}")
# Out:
#     Year Revenue (Millions USD)
# 11  2013                 $8,887
# 12  2012                 $9,551
# 13  2011                 $9,474
# 14  2010                 $9,078
# 15  2009                 $8,806

# %%
tesla_data = yf.download('TSLA', start='2020-01-01', end='2024-01-01')

def make_graph(data, title):
    plt.figure(figsize=(10, 6))
    plt.plot(data.index, data['Close'], label='Tesla Stock Price', color='blue')
    plt.title(title)
    plt.xlabel('Date')
    plt.ylabel('Stock Price (USD)')
    plt.grid(True)
    plt.legend()
    plt.show()

make_graph(tesla_data, 'Tesla Stock Price (2020-2024)')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
import yfinance as yf
import matplotlib.pyplot as plt
gme_data = yf.download('GME', start='2020-01-01', end='2024-01-01')

def make_graph(data, title):
    plt.figure(figsize=(10, 6))
    plt.plot(data.index, data['Close'], label='GameStop Stock Price', color='green')
    plt.title(title)
    plt.xlabel('Date')
    plt.ylabel('Stock Price (USD)')
    plt.grid(True)
    plt.legend()
    plt.show()

make_graph(gme_data, 'GameStop Stock Price (2020-2024)')
# Out:
# [*********************100%***********************]  1 of 1 completed
